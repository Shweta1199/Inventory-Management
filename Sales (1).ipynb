# %%
import json

fd = open("Store_inventory.json",'r')
r = fd.read()
fd.close()

products = json.loads(r)



print("Welcome to shop")


ui_prod = input("Enter the product Id: ")
ui_quan = int(input("Enter the quantity of the Product: "))

for i in products.keys():
    while ui_prod == i:
        if ui_quan <= products[i]['qn']:
            print("****************************************")
            print("             product:",products[ui_prod]['name'])
            print("               price:",products[ui_prod]['pr'])
            print(" Manufacturing Brand:",products[ui_prod]['brand'])
            print("****************************************")
            print("----------BILLING DETAILS:---------- ")
            print("Total Amount: ",products[ui_prod]['pr']*ui_quan) 
            print("Enjoy Your Day")
            print("Thank You. Visit Again")
            print("**********************************")
            products[ui_prod]["qn"] = products[ui_prod]["qn"] - ui_quan
        else:
            print("Sorry. Stock of product you enterd is: ",products[ui_prod]['qn'],"\nPlease accept our apologies for this inconvenience")
        break
if ui_prod not in products.keys():
   print("Sorry. No product found for ID: ",ui_prod,"\Please enter valid product ID")
    
    
js = json.dumps(products)

fd = open("products.json",'w')
fd.write(js)
fd.close()
## The sold items information is stored on sales.json
fd = open("sales.json",'r')
trans = fd.read()
fd.close()

sales = json.loads(trans)
num = len(sales)+1

sales[num] = {'prod':ui_prod, 'quan' : ui_quan, 'amount': products[ui_prod]['pr'] * ui_quan}
sale = json.dumps(sales)

fd = open("sales.json",'w')
fd.write(sale)
fd.close()
# Out:
# Welcome to shop
# Enter the product Id: 1014
# Enter the quantity of the Product: 2
# ****************************************
#              product: Mom's Magic Cashew
#                price: 80
#  Manufacturing Brand: Sunfeast
# ****************************************
# ----------BILLING DETAILS:----------
# Total Amount:  160
# Enjoy Your Day
# Thank You. Visit Again
# **********************************

# %%
products
# Out:
# {'1001': {'name': 'Choco Cake',
#   'pr': 34,
#   'qn': 100,
#   'brand': 'Nestle',
#   'Dis': '0%'},
#  '1002': {'name': 'Milk Cake',
#   'pr': 800,
#   'qn': 98,
#   'brand': 'G0',
#   'Dis': '5%'},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 100, 'brand': 'Coco', 'Dis': '2%'},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 1000, 'brand': 'Choco', 'Dis': '0%'},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 98, 'brand': 'Lexi', 'Dis': '0%'},
#  '1006': {'name': 'Phone',
#   'pr': 50000,
#   'qn': 8,
#   'brand': 'Apple',
#   'Dis': '10%'},
#  '1007': {'name': 'Mic',
#   'pr': 1500,
#   'qn': 0,
#   'brand': 'Samsung',
#   'Dis': '15%'},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5, 'brand': 'Levi', 'Dis': '5%'},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10, 'Dis': '10%'},
#  '1010': {'name': 'Lotte Choco Pie', 'pr': 110, 'qn': 95, 'brand': 'Lotte'},
#  '1011': {'name': 'Britania Chocolate cake',
#   'pr': 120,
#   'qn': 100,
#   'brand': 'Britania',
#   'Dis': '0%'},
#  '1012': {'name': 'Pillsbury cookes cake',
#   'pr': 90,
#   'qn': 200,
#   'brand': 'Pillsbury',
#   'Dis': '3%'},
#  '1013': {'name': 'Kraft Oreo Soft Cake',
#   'pr': 249,
#   'qn': 120,
#   'brand': 'Ore0',
#   'Dis': '5%'},
#  '1014': {'name': "Mom's Magic Cashew",
#   'pr': 80,
#   'qn': 166,
#   'brand': 'Sunfeast',
#   'Dis': '2%'},
#  '1015': {'name': 'Cadbury Oreo chacolate',
#   'pr': 60,
#   'qn': 181,
#   'brand': 'Cadbury',
#   'Dis': '0%'},
#  '1016': {'name': 'Betty Croker Pancake',
#   'pr': 346,
#   'qn': 188,
#   'brand': 'Betty Croker',
#   'Dis': '5%'},
#  '1017': {'name': 'Parle G Original',
#   'pr': 67,
#   'qn': 140,
#   'brand': 'Parle',
#   'Dis': '2%'},
#  '1018': {'name': 'Lays Potato Chips',
#   'pr': 30,
#   'qn': 450,
#   'brand': "Lay's",
#   'Dis': '5%'},
#  '1019': {'name': 'Bingo! Mad Angle',
#   'pr': 25,
#   'qn': 440,
#   'brand': 'Bingo!',
#   'Dis': '0%'},
#  '1020': {'name': "Kellogg's pringles",
#   'pr': 85,
#   'qn': 396,
#   'brand': "Kellog's",
#   'Dis': '5%'},
#  '1021': {'name': "Dorito's Nacho Chips",
#   'pr': 90,
#   'qn': 360,
#   'brand': "Dorito's",
#   'Dis': '0%'},
#  '1022': {'name': 'Thums Up Soft Drink',
#   'pr': 40,
#   'qn': 60,
#   'brand': 'Thums Up',
#   'Dis': '0%'},
#  '1023': {'name': 'Svami Soda Water',
#   'pr': 55,
#   'qn': 70,
#   'brand': 'Svami',
#   'Dis': '0%'},
#  '1024': {'name': 'Coca-Cola',
#   'pr': 65,
#   'qn': 60,
#   'brand': 'Coca Cola',
#   'Dis': '5%'},
#  '1025': {'name': 'Sprite Lime Flavor',
#   'pr': 89,
#   'qn': 40,
#   'brand': 'Sprite',
#   'Dis': '10%'},
#  '1026': {'name': 'Colgate Maxfresh',
#   'pr': 215,
#   'qn': 55,
#   'brand': 'Colgate',
#   'Dis': '5%'},
#  '1027': {'name': 'Pepsodent Gum Care',
#   'pr': 300,
#   'qn': 150,
#   'brand': 'Pepsodent',
#   'Dis': '0%'},
#  '1028': {'name': 'Dabur Amla Hair Oil',
#   'pr': 247,
#   'qn': 100,
#   'brand': 'DABUR',
#   'Dis': '10%'},
#  '1029': {'name': 'Nivea Men Face Wash',
#   'pr': 149,
#   'qn': 98,
#   'brand': 'Nivea',
#   'Dis': '5%'},
#  '1030': {'name': 'Himalaya Herbal Face wash',
#   'pr': 104,
#   'qn': 200,
#   'brand': 'Himalaya',
#   'Dis': '10%'},
#  '1031': {'name': 'Villain Perfume men',
#   'pr': 500,
#   'qn': 50,
#   'brand': 'Villain ',
#   'Dis': '50%'}}

# %% [markdown]
# ### Update Inventory after products sold

# %%
sales = {1 : {'prod':ui_prod, 'quan':ui_quan, 'amount':products[ui_prod]['pr']*ui_quan}}
sal = json.dumps(sales)

fd = open("sales.json",'w')
fd.write(sal)
fd.close()
