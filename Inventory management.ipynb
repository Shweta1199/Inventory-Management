# %%
Store_inventory = {"1001": {"name": "Choco Cake","pr": 34, "qn": 100, "brand":"Nestle", "Dis":"0%"},
                    "1002": {"name": "Milk Cake", "pr": 800, "qn": 100, "brand":"G0", "Dis":"5%"},
                    "1003": {"name": "Drink", "pr": 85, "qn": 100, "brand":"Coco", "Dis":"2%" },
                    "1004": {"name": "Candy", "pr": 5, "qn": 1000, "brand":"Choco", "Dis":"0%"},
                    "1005": {"name": "Pen", "pr": 20, "qn": 100, "brand":"Lexi", "Dis":"0%"}, 
                    "1006": {"name": "Phone", "pr": 50000, "qn": 10, "brand":"Apple", "Dis":"10%"},
                    "1007": {"name": "Mic", "pr": 1500, "qn": 0, "brand":"Samsung", "Dis":"15%"}, 
                    "1008": {"name": "Case", "pr": 599, "qn": 5, "brand":"Levi", "Dis":"5%"},
                    "1009": {"name": "Keyboard", "pr": 1999, "qn": 10, "Dis":"10%"},
                    "1010" : {"name":"Lotte Choco Pie", "pr":110,  "qn":95, "brand":"Lotte"},
                    "1011" : {"name":"Britania Chocolate cake", "pr":120,  "qn":100,   "brand":"Britania", "Dis":"0%" },
                    "1012" : {"name":"Pillsbury cookes cake",   "pr":90,   "qn":200,   "brand":"Pillsbury", "Dis":"3%"},
                    "1013" : {"name":"Kraft Oreo Soft Cake",    "pr":249,  "qn":120,   "brand":"Ore0", "Dis":"5%"},
                    "1014" : {"name":"Mom's Magic Cashew",      "pr":80,   "qn":180,   "brand":"Sunfeast", "Dis":"2%"},
                    "1015" : {"name":"Cadbury Oreo chacolate",  "pr":60,   "qn":185,   "brand":"Cadbury", "Dis":"0%"},
                    "1016" : {"name":"Betty Croker Pancake",    "pr":346,  "qn":190,  "brand":"Betty Croker", "Dis":"5%"},
                    "1017" : {"name":"Parle G Original",        "pr":67,   "qn":140,   "brand":"Parle", "Dis":"2%"},
                    "1018" : {"name":"Lays Potato Chips",       "pr":30,   "qn":450,   "brand":"Lay's", "Dis":"5%"},
                    "1019" : {"name":"Bingo! Mad Angle",        "pr":25,   "qn":440,   "brand":"Bingo!", "Dis":"0%"},
                    "1020": {"name":"Kellogg's pringles",      "pr":85,   "qn":400,  "brand":"Kellog's", "Dis":"5%"},
                    "1021" : {"name":"Dorito's Nacho Chips",    "pr":90,   "qn":360,   "brand":"Dorito's", "Dis":"0%"},
                    "1022": {"name":"Thums Up Soft Drink",     "pr":40,   "qn":60,   "brand":"Thums Up", "Dis":"0%"},
                    "1023" : {"name":"Svami Soda Water",        "pr":55,   "qn":70,    "brand":"Svami", "Dis":"0%"},
                    "1024" : {"name":"Coca-Cola",               "pr":65,   "qn":60,   "brand":"Coca Cola", "Dis":"5%"},
                    "1025" : {"name":"Sprite Lime Flavor",      "pr":89,   "qn":40,    "brand":"Sprite", "Dis":"10%"},
                    "1026" : {"name":"Colgate Maxfresh",        "pr":215,  "qn":55,   "brand":"Colgate", "Dis":"5%"},
                    "1027" : {"name":"Pepsodent Gum Care",      "pr":300,  "qn":150,   "brand":"Pepsodent","Dis":"0%"},
                    "1028" : {"name":"Dabur Amla Hair Oil",     "pr":247,  "qn":100,   "brand":"DABUR", "Dis":"10%"},
                    "1029" : {"name":"Nivea Men Face Wash",     "pr":149,  "qn":98,    "brand":"Nivea", "Dis":"5%"},
                    "1030" : {"name":"Himalaya Herbal Face wash","pr":104, "qn":200,   "brand":"Himalaya","Dis":"10%"}}

# %%
import json
js = json.dumps(Store_inventory)

# %%
fd = open("Store_inventory.json","w")
fd.write(js)
fd.close()

# %% [markdown]
# ### Read data from Json

# %%
fd = open("Store_inventory.json",'r')

r = fd.read()

fd.close()

# %%
Store_inventory = json.loads(r)

# %%
Store_inventory
# Out:
# {'1001': {'name': 'Choco Cake',
#   'pr': 34,
#   'qn': 100,
#   'brand': 'Nestle',
#   'Dis': '0%'},
#  '1002': {'name': 'Milk Cake',
#   'pr': 800,
#   'qn': 100,
#   'brand': 'G0',
#   'Dis': '5%'},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 100, 'brand': 'Coco', 'Dis': '2%'},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 1000, 'brand': 'Choco', 'Dis': '0%'},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 100, 'brand': 'Lexi', 'Dis': '0%'},
#  '1006': {'name': 'Phone',
#   'pr': 50000,
#   'qn': 10,
#   'brand': 'Apple',
#   'Dis': '10%'},
#  '1007': {'name': 'Mic',
#   'pr': 1500,
#   'qn': 0,
#   'brand': 'Samsung',
#   'Dis': '15%'},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5, 'brand': 'Levi', 'Dis': '5%'},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10, 'Dis': '10%'},
#  '1010': {'name': 'Lotte Choco Pie', 'pr': 110, 'qn': 95, 'brand': 'Lotte'},
#  '1011': {'name': 'Britania Chocolate cake',
#   'pr': 120,
#   'qn': 100,
#   'brand': 'Britania',
#   'Dis': '0%'},
# ...

# %% [markdown]
# ### Add New Item into Inventory

# %%
prod_id = input("Enter product id:")
name = str(input("Enter name:"))
pr = int(input("Enter price:"))
qn = int(input("Enter quantity:"))
brand = input("Enter brand:")
Dis = input("Enter discount:")

Store_inventory[prod_id] = {'name': name, 'pr': pr, 'qn': qn, 'brand': brand, 'Dis': Dis}

js = json.dumps(Store_inventory)

fd = open("Store_inventory.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id:1031
# Enter name:Villain Perfume men
# Enter price:500
# Enter quantity:50
# Enter brand:Villain
# Enter discount:50%

# %%
Store_inventory
# Out:
# {'1001': {'name': 'Choco Cake',
#   'pr': 34,
#   'qn': 100,
#   'brand': 'Nestle',
#   'Dis': '0%'},
#  '1002': {'name': 'Milk Cake',
#   'pr': 800,
#   'qn': 100,
#   'brand': 'G0',
#   'Dis': '5%'},
#  '1003': {'name': 'Drink', 'pr': 85, 'qn': 100, 'brand': 'Coco', 'Dis': '2%'},
#  '1004': {'name': 'Candy', 'pr': 5, 'qn': 1000, 'brand': 'Choco', 'Dis': '0%'},
#  '1005': {'name': 'Pen', 'pr': 20, 'qn': 100, 'brand': 'Lexi', 'Dis': '0%'},
#  '1006': {'name': 'Phone',
#   'pr': 50000,
#   'qn': 10,
#   'brand': 'Apple',
#   'Dis': '10%'},
#  '1007': {'name': 'Mic',
#   'pr': 1500,
#   'qn': 0,
#   'brand': 'Samsung',
#   'Dis': '15%'},
#  '1008': {'name': 'Case', 'pr': 599, 'qn': 5, 'brand': 'Levi', 'Dis': '5%'},
#  '1009': {'name': 'Keyboard', 'pr': 1999, 'qn': 10, 'Dis': '10%'},
#  '1010': {'name': 'Lotte Choco Pie', 'pr': 110, 'qn': 95, 'brand': 'Lotte'},
#  '1011': {'name': 'Britania Chocolate cake',
#   'pr': 120,
#   'qn': 100,
#   'brand': 'Britania',
#   'Dis': '0%'},
# ...
